# %%
import pandas as pd

#carico dataset merged_adm1_wide.parquet
df = pd.read_parquet("../../data/merged/merged_adm1_wide.parquet")
df
# Out:
#       Country location_name_full   Level 1  Area adm1_pcode adm2_pcode  \
# 0         AFG        Afghanistan     Kabul  None       AF01
# 1         AFG        Afghanistan     Kabul  None       AF01
# 2         AFG        Afghanistan     Kabul  None       AF01
# 3         AFG        Afghanistan     Kabul  None       AF01
# 4         AFG        Afghanistan     Kabul  None       AF01
# ...       ...                ...       ...   ...        ...        ...
# 10019     ZWE           Zimbabwe  Masvingo  None       ZW18
# 10020     ZWE           Zimbabwe  Masvingo  None       ZW18
# 10021     ZWE           Zimbabwe  Masvingo  None       ZW18
# 10022     ZWE           Zimbabwe  Masvingo  None       ZW18
# 10023     ZWE           Zimbabwe  Masvingo  None       ZW18
#
#             From                  To   Validity period     Date of analysis  \
# 0     2017-08-01 2017-11-30 23:59:59           current  2017-08-01T00:00:00
# 1     2018-08-01 2018-10-31 23:59:59           current  2018-08-01T00:00:00
# 2     2018-11-01 2019-02-28 23:59:59  first projection  2018-11-01T00:00:00
# 3     2019-08-01 2019-10-31 23:59:59           current  2019-08-01T00:00:00
# 4     2019-11-01 2020-03-31 23:59:59  first projection  2019-11-01T00:00:00
# ...          ...                 ...               ...                  ...
# 10019 2019-06-01 2019-09-30 23:59:59           current  2019-06-01T00:00:00
# 10020 2019-10-01 2019-12-31 23:59:59  first projection  2019-10-01T00:00:00
# 10021 2020-02-01 2020-06-30 23:59:59           current  2020-02-01T00:00:00
# 10022 2020-10-01 2020-12-31 23:59:59           current  2020-10-01T00:00:00
# 10023 2021-01-01 2021-03-31 23:59:59  first projection  2021-01-01T00:00:00
#
#        ...  gdelt_verbal_coop_tone gdelt_material_coop_events  \
# 0      ...               -2.391549                     6228.0
# 1      ...               -2.347104                     3932.0
# 2      ...               -1.569367                     6144.0
# 3      ...               -2.526242                     4653.0
# 4      ...               -2.124733                     8939.0
# ...    ...                     ...                        ...
# 10019  ...               -1.661450                      390.0
# 10020  ...               -1.139974                      339.0
# 10021  ...               -1.743440                      698.0
# 10022  ...               -0.543956                      240.0
# 10023  ...               -0.809510                      344.0
#
#        gdelt_material_coop_mentions  gdelt_material_coop_tone  \
# 0                           34053.0                 -3.335023
# 1                           22156.0                 -3.595366
# 2                           33598.0                 -3.028408
# 3                           26735.0                 -3.212505
# 4                           48517.0                 -2.820670
# ...                             ...                       ...
# 10019                        2041.0                 -1.729670
# 10020                        1867.0                 -1.902814
# 10021                        3802.0                 -1.614034
# 10022                        1348.0                 -0.123948
# 10023                        1643.0                 -1.243817
#
#        gdelt_verbal_conflict_events  gdelt_verbal_conflict_mentions  \
# 0                            8278.0                         47734.0
# 1                            5194.0                         31849.0
# 2                            7958.0                         45917.0
# 3                            7279.0                         41200.0
# 4                            8613.0                         46929.0
# ...                             ...                             ...
# 10019                         713.0                          3780.0
# 10020                         455.0                          2562.0
# 10021                         814.0                          4467.0
# 10022                         280.0                          1469.0
# 10023                         238.0                          1214.0
#
#        gdelt_verbal_conflict_tone  gdelt_material_conflict_events  \
# 0                       -4.895209                         13942.0
# 1                       -5.099749                         10149.0
# 2                       -3.980824                         10838.0
# 3                       -4.360610                         10481.0
# 4                       -3.467968                         10706.0
# ...                           ...                             ...
# 10019                   -3.642161                           459.0
# 10020                   -3.109481                           372.0
# 10021                   -3.357042                           676.0
# 10022                   -2.400386                           204.0
# 10023                   -3.012257                           357.0
#
#        gdelt_material_conflict_mentions  gdelt_material_conflict_tone
# 0                               91166.0                     -6.719388
# 1                               67189.0                     -6.445504
# 2                               70564.0                     -6.438398
# 3                               64091.0                     -5.635617
# 4                               61631.0                     -5.146167
# ...                                 ...                           ...
# 10019                            2506.0                     -4.719800
# 10020                            1866.0                     -4.177619
# 10021                            3439.0                     -4.882919
# 10022                             987.0                     -3.927138
# 10023                            1563.0                     -5.265559
#
# [10024 rows x 62 columns]

# %%
import altair as alt
ultimo_aggiornamento = df.groupby(['Country', 'adm1_pcode'])['From'].transform('max')

df_attuali = pd.melt(df[df["From"] == ultimo_aggiornamento], id_vars=['Country'], value_vars=['phase_3_number', 'phase_4_number', 'phase_5_number'])
df_chart = df_attuali.groupby(['Country', "variable"])['value'].sum().reset_index()
df_chart
# Out:
#     Country        variable      value
# 0       AFG  phase_3_number  6736422.0
# 1       AFG  phase_4_number  1671024.0
# 2       AFG  phase_5_number        0.0
# 3       AGO  phase_3_number  1177925.0
# 4       AGO  phase_4_number   426109.0
# ..      ...             ...        ...
# 139     ZMB  phase_4_number     9907.0
# 140     ZMB  phase_5_number        0.0
# 141     ZWE  phase_3_number  2611639.0
# 142     ZWE  phase_4_number   768594.0
# 143     ZWE  phase_5_number        0.0
#
# [144 rows x 3 columns]

# %%
chart = alt.Chart(df_chart).mark_bar().encode(
    x= alt.X("value:Q", stack='normalize'),
    y="Country:N",
    color="variable:N",
    tooltip=['Country', 'variable', 'value']
).properties(width=1000)
chart
# Out:
# alt.Chart(...)
