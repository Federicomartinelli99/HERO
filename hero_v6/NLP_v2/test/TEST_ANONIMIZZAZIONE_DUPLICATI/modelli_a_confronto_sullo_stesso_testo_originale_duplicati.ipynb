# %%
import pandas as pd

# %%
df = pd.read_csv("data/df_duplicati.csv")

# %%
df
# Out:
#     Unnamed: 0                                       nome_file        paese  \
# 0            7  El_Salvador_Mar_2025_-_Feb_2026_KeyResults.txt  El Salvador
# 1            9     Honduras_Mar_2025_-_Feb_2026_KeyResults.txt     Honduras
# 2           23    Guatemala_Mar_2025_-_Feb_2026_KeyResults.txt    Guatemala
# 3           31  El_Salvador_Jun_2020_-_Aug_2020_KeyResults.txt  El Salvador
# 4           35     Honduras_Jun_2020_-_Aug_2020_KeyResults.txt     Honduras
# 5           59    Guatemala_Jun_2020_-_Aug_2020_KeyResults.txt    Guatemala
# 6           68  El_Salvador_Jun_2022_-_Aug_2022_KeyResults.txt  El Salvador
# 7           70     Honduras_Jun_2022_-_Aug_2022_KeyResults.txt     Honduras
# 8           74    Guatemala_Jun_2022_-_Aug_2022_KeyResults.txt    Guatemala
# 9          162  El_Salvador_Nov_2018_-_Apr_2019_KeyResults.txt  El Salvador
# 10         167     Honduras_Nov_2018_-_Apr_2019_KeyResults.txt     Honduras
# ...

# %%
df["Llama_3_1_8B_8bit_anonimo_prompt_gemini"][0]
# Out:
# '[SHOCKS AND DRIVERS]: \nThe underlying causes of the current food insecurity situation are multifaceted, with climatic variability, high food prices, and low food reserves contributing to the decline in acute food security. The depletion of staple grain reserves, erratic rainfall, and pest outbreaks have constrained food access and availability, exacerbating the crisis. Additionally, the increasing cost of basic food items and reduced employment opportunities in the agricultural sector have further worsened the situation.\n\n[CURRENT FOOD SECURITY DATA]: \nAn estimated 100,000 people (16 percent of the analysed population) are classified in IPC Phase 3 or above (Crisis or worse), requiring urgent action to safeguard livelihoods and address food consumption gaps. Specifically, 97,000 people are in IPC Phase 3 (Crisis) and 3,000 are in IPC Phase 4 (Emergency). The Ch’orti’ micro-region is the most severely affected, with 25 percent of its population in Phase 3 or higher, while Ocotepe
# ...

# %%
df["testo_originale"][0]
# Out:
# '[SHOCKS AND DRIVERS]: \nThe affected areas are experiencing a decline in acute food security due to climatic variability, high food prices, and low food reserves. Conflict, displacement, and disease outbreaks are not significant drivers in this region. However, economic factors, such as low employment opportunities in the agricultural sector and rising market prices, are contributing to the crisis. Additionally, agriculture is severely impacted by crop losses caused by prolonged droughts, erratic rainfall, and pest outbreaks, further exacerbating food access and availability constraints.\n\n[CURRENT FOOD SECURITY DATA]: \nApproximately 100,000 people (16 percent of the analysed population) are classified in IPC Phase 3 or above (Crisis or worse), requiring urgent action. This includes 97,000 people in IPC Phase 3 (Crisis) and 3,000 in IPC Phase 4 (Emergency). The Ch’orti’ micro-region is the most severely affected, with 25 percent of its population in Phase 3 or higher, while other 
# ...

# %%
df[df["testo_originale"] =="During the current period of March to June 2024 which coincides with the post-harvest, 88,000 people (15 percent of the analysed population) are experiencing IPC Phase 3 or above (Crisis or worse). Of this population, 81,000 are in Crisis (IPC Phase 3) and 7,000 in Emergency (IPC Phase 4). Key drivers include decreased purchasing power, high prices for basic foods, fuel, and agricultural inputs, along with low food reserves and reliance on food purchases.\nThe seasonal hunger period from July to September 2024 will see the number of people facing high acute food insecurity (IPC Phase 3 or above) rise to 123,000 (21 percent of the analysed population). The Ch'orti' micro-region will remain the most affected, classified in Phase 3 with 24 percent of its population in IPC Phase 3 or above, including 4 percent in Phase 4. The other three micro-regions (Ocotepeque, Güija, and Cayaguanca) will be classified in IPC Phase 2 (Stressed) in both current and projected periods, but the number of people in acute food insecurity will increase in the first projected period.\nFrom October 2024 to February 2025, a period of higher income generation is expected due to increased demand for labour for crop harvesting. However, 94,000 people (16 percent of the analysed population) will still be in Phase 3 or above."]
# Out:
# "[SHOCKS AND DRIVERS]:\nThe affected areas are experiencing a decline in acute food security due to climatic variability, high food prices, and low food reserves. These factors have led to a moderate but sustained decline in food security, primarily affecting the population's access to and availability of food.\n\n[CURRENT FOOD SECURITY DATA]:\nAn estimated 100,000 people (16 percent of the analysed population) are classified in IPC Phase 3 or above (Crisis or worse), requiring urgent action. This includes approximately 97,000 people in IPC Phase 3 (Crisis) and 3,000 in IPC Phase 4 (Emergency). The Ch’orti’ micro-region is the most severely affected, with 25 percent of its population in Phase 3 or higher.\n\n[PROJECTED FOOD SECURITY DATA]:\nThe situation is expected to deteriorate during the seasonal hunger period, with 139,000 people (23 percent) projected to be in Phase 3 or above, including 15,000 in Phase 4 (Emergency). However, a slight improvement is anticipated from October 20
# ...

# %%
df["Llama_3_2_3B_anonimo"][0]
# Out:
# "[SHOCKS AND DRIVERS]:\nThe affected areas are experiencing a decline in acute food security due to climatic variability, high food prices, and low food reserves. Economic factors, such as rising market prices, are further exacerbating the situation. Agriculture is also a significant driver, with crop losses caused by prolonged droughts, erratic rainfall, and pest outbreaks. Conflict and displacement are not explicitly mentioned, but the report suggests that the population is vulnerable to these shocks. Disease outbreaks are also a concern, as they can further strain the already limited resources.\n\n[CURRENT FOOD SECURITY DATA]:\nThe current period (March to May) has seen an estimated 100,000 people (16 percent of the analysed population) classified in IPC Phase 3 or above (Crisis or worse). This includes approximately 97,000 people in IPC Phase 3 (Crisis) and 3,000 in IPC Phase 4 (Emergency). The Ch'orti' micro-region is the most severely affected, with 25 percent of its population
# ...

# %%
df["Llama_3_1_8B_anonimo"][0]
# Out:
# "[SHOCKS AND DRIVERS]:\nThe affected areas are experiencing a decline in acute food security due to climatic variability, high food prices, and low food reserves. These factors have led to a moderate but sustained decline in food security, primarily affecting the population's access to and availability of food.\n\n[CURRENT FOOD SECURITY DATA]:\nApproximately 100,000 people (16 percent of the analysed population) are classified in IPC Phase 3 or above (Crisis or worse), requiring urgent action to safeguard livelihoods and address food consumption gaps. This includes approximately 97,000 people in IPC Phase 3 (Crisis) and 3,000 in IPC Phase 4 (Emergency). The Ch’orti’ micro-region is the most severely affected, with 25 percent of its population in Phase 3 or higher.\n\n[PROJECTED FOOD SECURITY DATA]:\nDuring the first projection period (June to September 2025), 139,000 people (23 percent) are projected to be in Phase 3 or above, including 15,000 in Phase 4 (Emergency). The Ch’orti’ reg
# ...

# %%
df["Llama_3_1_8B_anonimo_promtp_in_context"][0]
# Out:
# '[SHOCKS AND DRIVERS]: The affected areas are experiencing a decline in acute food security, driven by climatic variability, high food prices, and low food reserves. Crop losses are caused by prolonged droughts, erratic rainfall, and pest outbreaks, which are further exacerbated by the increasing cost of basic food items. These factors, combined with reduced employment opportunities in the agricultural sector, contribute to the overall food insecurity.\n\n[CURRENT FOOD SECURITY DATA]: An estimated 100,000 people (16 percent of the analyzed population) are classified in IPC Phase 3 or above (Crisis or worse), requiring urgent action to safeguard livelihoods and address food consumption gaps. This includes approximately 97,000 people in IPC Phase 3 (Crisis) and 3,000 in IPC Phase 4 (Emergency). The most severely affected area has 25 percent of its population in Phase 3 or higher, while other regions remain in Phase 2 (Stressed), despite hosting a significant population in Crisis.\n\n[P
# ...

# %%
df[df["nome_file"] == "Honduras_Mar_2025_-_Feb_2026_KeyResults.txt"]["Llama_3_1_8B_anonimo_promtp_in_context"][1]
# Out:
#                                         nome_file        paese  \
# 0  Afghanistan_Nov_2017_-_Feb_2018_KeyResults.txt  Afghanistan
# 1  South_Sudan_Oct_2022_-_Jul_2023_KeyResults.txt  South Sudan
# 2     Honduras_Dec_2012_-_Jan_2013_KeyResults.txt     Honduras
#
#                periodo inizio_periodo fine_periodo  \
# 0  Nov 2017 / Feb 2018       Nov 2017     Feb 2018
# 1  Oct 2022 / Jul 2023       Oct 2022     Jul 2023
# 2  Dec 2012 / Jan 2013       Dec 2012     Jan 2013
#
#                                      testo_originale  \
# 0  During the 2017 post-harvest season, 33% of th...
# 1  About 6.6 million people, or over half of Sout...
# 2  The Valle and Choluteca region is classified P...
#
#                                       report_anonimo  \
# 0  [SHOCKS AND DRIVERS]: \nThe underlying causes ...
# 1  [SHOCKS AND DRIVERS]: \nThe underlying causes ...
# 2  [SHOCKS AND DRIVERS]: \nThe underlying causes ...
#
#                            Qwen_2_5_32B_Q6_K_anonimo
# ...

# %%
df["Llama_3_1_8B_8bit_anonimo"][0]
# Out:
# esempio 0 testo originale:
# During the 2017 post-harvest season, 33% of the population were classified in “Crisis” (IPC Phase 3) and “Emergency” (IPC Phase 4) in the North Eastern Region covering the provinces of Badakhshan, Baghlan, Kunduz and Takhar.
#
# Kohistan, Raghistan, Yawan, Koran o Minjan, Yamgan, Darwaz Bala, Darwaz Payin, Kufab, Shiki, Wakhan, Zebak, Arghanj Khwah, Eshkashim, Shighnan districts of Badakhshan province were the most food insecure districts with 30% to 45% food insecure households, corresponds to 120 293 people in emergency situation (IPC phase 4).
#
# ...

# %%
df["Llama_3_1_8B_8bit_anonimo_promtp_in_context"][0]

# %%
df["Qwen_2_5_32B_Q6_K_anonimo"][0]

# %%
df2 = pd.read_csv("data/esempi_giusti_qwen_32B.csv")
df2

# %%
df2["Qwen_2_5_32B_Q6_K_anonimo"][0]

# %%
df2["testo_originale"][0]

# %%
for indice in range(0,len(df2)):
    print(f"esempio {indice} testo originale:")
    print(df2["testo_originale"][indice])
    print("")
    print(f"esempio {indice} testo anonimizzato:")
    print(df2["Qwen_2_5_32B_Q6_K_anonimo"][indice])
    print("---------------------------------------")
